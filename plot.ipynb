# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("24.DAT", sep='\t ', skiprows=12, names=['Q', 'I', 'I2'])

# %%
df34
# Out:
#         mod_q  intensity     error  delta_mod_q
# 0    0.003947   0.181396  0.073229     0.000914
# 1    0.004121   0.181269  0.048119     0.000937
# 2    0.004303   0.161248  0.030770     0.000946
# 3    0.004493   0.190091  0.022316     0.000961
# 4    0.004691   0.148156  0.016583     0.000973
# ..        ...        ...       ...          ...
# 134  0.622429   0.001658  0.000091     0.013139
# 135  0.645953   0.001737  0.000117     0.013651
# 136  0.670366   0.001701  0.000164     0.014177
# 137  0.695702   0.001217  0.000266     0.014705
# 138  0.721995   0.000500  0.000564     0.015233
#
# [139 rows x 4 columns]

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', color='white', linestyle='--', data=df24, ax=ax, label='sample6 25C')
sns.lineplot(x='mod_q', y='intensity', color='red', data=df28, ax=ax, label="sample 6 50C")
ax.set(ylabel='Intensity', xlabel='q', yscale='log')
fig.savefig('sample 6.jpeg')

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', data=df24, ax=ax, label="sample 6 25C")
sns.lineplot(x='mod_q', y='intensity', data=df28, ax=ax, label="sample 6 50C")
sns.lineplot(x='mod_q', y='intensity', data=df34, ax=ax, label="sample 2")
sns.lineplot(x='mod_q', y='intensity', data=df38, ax=ax, label="sample 3")
sns.lineplot(x='mod_q', y='intensity', data=df42, ax=ax, label="sample 9")
ax.set(ylabel='Intensity', xlabel='q', yscale='log')
ax.legend()
fig.savefig('All.jpeg')

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', data=df24, ax=ax, label="sample 6 25C")
sns.lineplot(x='mod_q', y='intensity', data=df28, ax=ax, label="sample 6 50C")
sns.lineplot(x='mod_q', y='intensity', data=df34, ax=ax, label="sample 2")
sns.lineplot(x='mod_q', y='intensity', data=df38, ax=ax, label="sample 3")
sns.lineplot(x='mod_q', y='intensity', data=df42, ax=ax, label="sample 9")
ax.set(yscale='log',ylim=[0.0004, 0.01], xlim=[0.08,0.14])
ax.set(ylabel='Intensity', xlabel='q', yscale='log')
fig.savefig('All_around0.1.jpeg')

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', color='red', sizes='25', data=df42, ax=ax)
ax.set(yscale='log')
fig.savefig('42.jpeg')

# %%
#a66= np.loadtxt("A70.txt",skiprows=3)
#plt.semilogy(a66[:,0],a66[:,1]);

# %%
#old style of plotting 4k temperature
plt.style.use('dark_background')
fig, ax =plt.subplots(1,2)
fig.set_size_inches(8,5)
ax[0].plot(df24['mod_q'],df24['intensity'], 'r', markersize=1 )
ax[0].errorbar(df24['mod_q'],df24['intensity'],yerr=df24['error'])
ax[0].set(yscale='log',ylabel='Intensity ', xlabel='q')

ax[1].plot(df28['mod_q'],df28['intensity'],'b' )
ax[1].errorbar(df28['mod_q'],df28['intensity'],yerr=df28['error'])
ax[1].set( yscale='log', xlabel='q')
ax[1].set_title('sample 6 25C')
ax[0].set_title('sample 6 50C')
fig.savefig('sample_6error.png')

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', color='white', linestyle='--', data=df24, ax=ax, label='sample6 25C')
ax.set(ylabel='Intensity', xlabel='q', yscale='log')
fig.savefig('sample 6.jpeg')

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', color='white', linestyle='--', data=df24, ax=ax, label='sample6 25C')
sns.lineplot(x='mod_q', y='intensity', color='red', data=df28, ax=ax, label="sample 6 50C")
ax.set(ylabel='Intensity', xlabel='q', yscale='log')
fig.savefig('sample 6.jpeg')

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', color='white', linestyle='--', data=df24, ax=ax, label='sample6 25C')
sns.lineplot(x='mod_q', y='intensity', color='red', data=df28, ax=ax, label="sample 6 50C")
ax.set(ylabel='Intensity', xlabel='q', yscale='log')
fig.savefig('sample 6.jpeg')

# %%
plt.style.use('dark_background')
fig, ax= plt.subplots(figsize=(20,8))
sns.lineplot(x='mod_q', y='intensity', color='white', linestyle='--', data=df24, ax=ax, label='sample6 25C')
sns.lineplot(x='mod_q', y='intensity', color='red', data=df28, ax=ax, label="sample 6 50C")
ax.set(ylabel='Intensity', xlabel='q', yscale='log')
fig.savefig('sample 6.jpeg')
