# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#all temperature with subtracting empty capillary
def alltemp_s( data10, data25, data40, data50, data25ah, data20ah, 
            data_ec10, data_ec25, data_ec40, data_ec50, data_ec25ah, data_ec20ah):
    dat=[data25, data10, data40, data50, data25ah, data20ah]
    df=[]
    for i in range(len(dat)):
        df.append(np.genfromtxt(dat[i], delimiter='\t',skip_header=12))
    df=np.array(df)
    q = df[:,:,0]  #size (6, 234, 3) so [:,:,0] gives q
    
    df_ec=[]
    dat_ec=[data_ec10, data_ec25, data_ec40, data_ec50, data_ec25ah, data_ec20ah]
    for i in range(len(dat_ec)):
        df_ec.append(np.genfromtxt(dat_ec[i], delimiter='\t',skip_header=12))
    df_ec=np.array(df_ec)
    
    I=[]
    for i in range(len(dat_ec)):
        I.append(df[i,:,1]-df_ec[i,:,1])   # substracting each temp empty capillary
    I=np.array(I)
    
    color=['red','blue','green','white','cyan','yellow']
    lev=['10K','25K','40K','50K','25K_ah','20K_ah']
    plt.style.use('dark_background')
    fig, ax= plt.subplots(figsize=(20,8))
    ax.set(ylabel='Intensity', xlabel='Q(A-1)')
    for i in range(len(dat)):
        fig=ax.plot(q[i,:],I[i,:], color=color[i],label=lev[i])
    ax.legend()
    ax.set_xlim([0.035, 1])
    ax.set_ylim([0, 2.5])
    return fig

# %%
#CH in temp (10,25, 40,50,25,20)

#Ch1: 40 µl miliQ water + 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol
#Ch2: 40 µl miliQ water + 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0013 mg AuNPs
#Ch3: 40 µl miliQ water + 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0066 mg AuNPs
#Ch4: 40 µl miliQ water + 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0132 mg AuNPs
#Ch5: 40 µl miliQ water + 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0264 mg AuNPs

# %%
# for ch1 ( 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol) 
alltemp_s('SCh1_00144_00001.dat', 'SCh1_00157_00001.dat',
        'SCh1_00170_00001.dat','SCh1_00183_00001.dat',
        'SCh1_00196_00001.dat','SCh1_00209_00001.dat',
         'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for ch2 ( 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0013 mg AuNPs 
alltemp_s('SCh2_00145_00001.dat', 'SCh2_00158_00001.dat',
        'SCh2_00171_00001.dat','SCh2_00184_00001.dat',
        'SCh2_00197_00001.dat','SCh2_00210_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for ch3 ( 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0066 mg AuNPs)
alltemp_s('SCh3_00146_00001.dat', 'SCh3_00159_00001.dat',
        'SCh3_00172_00001.dat','SCh3_00185_00001.dat',
        'SCh3_00198_00001.dat','SCh3_00211_00001.dat',
        'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for ch4 ( 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0132 mg AuNPs)
alltemp_s('SCh4_00147_00001.dat', 'SCh4_00160_00001.dat',
        'SCh4_00173_00001.dat','SCh4_00186_00001.dat',
        'SCh4_00199_00001.dat','SCh4_00212_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for ch5 ( 1 mg DPPC + 1 mg DOPC + 0.17 mg Chol + 0.0264 mg AuNPs)
alltemp_s('SCh5_00148_00001.dat', 'SCh5_00161_00001.dat',
        'SCh5_00174_00001.dat','SCh5_00187_00001.dat',
        'SCh5_00200_00001.dat','SCh5_00213_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
#DP in temp (10,25, 40,50,25,20)
#DP1: 40 µl miliQ water + 2 mg DPPC
#DP2: 40 µl miliQ water + 2 mg DPPC + 0.0013 mg AuNPs
#DP3: 40 µl miliQ water + 2 mg DPPC + 0.013 mg AuNPs

# %%
# for DP1 ( 2 mg DPPC)
alltemp_s('SDP1_00149_00001.dat', 'SDP1_00162_00001.dat',
        'SDP1_00175_00001.dat','SDP1_00188_00001.dat',
        'SDP1_00201_00001.dat','SDP1_00214_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for DP2 ( 2 mg DPPC + 0.0013 mg AuNPs)
alltemp_s('SDP2_00150_00001.dat', 'SDP2_00163_00001.dat',
        'SDP2_00176_00001.dat','SDP2_00189_00001.dat',
        'SDP2_00202_00001.dat','SDP2_00215_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for DP3 ( 2 mg DPPC + 0.013 mg AuNPs)
alltemp_s('SDP3_00151_00001.dat', 'SDP3_00164_00001.dat',
        'SDP3_00177_00001.dat','SDP3_00190_00001.dat',
        'SDP3_00203_00001.dat','SDP3_00216_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
#P in temp (10,25,40,50,25,20)
#P1: 40 µl miliQ water + 0.7 mg P19015 + 0.37 mg DPPC
#P2: 40 µl miliQ water + 0.7 mg P19015 + 0.37 mg DPPC + 0.0003 mg AuNPs
#P3: 40 µl miliQ water + 0.7 mg P19015 + 0.37 mg DPPC + 0.003 mg AuNPs

# %%
# for P1 ( 0.7 mg P19015 + 0.37 mg DPPC)
alltemp_s('SP1_00153_00001.dat', 'SP1_00166_00001.dat',
        'SP1_00179_00001.dat','SP1_00192_00001.dat',
        'SP1_00205_00001.dat','SP1_00218_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for P2 ( 0.7 mg P19015 + 0.37 mg DPPC)
alltemp_s('SP2_00154_00001.dat', 'SP2_00167_00001.dat',
        'SP2_00180_00001.dat','SP2_00193_00001.dat',
        'SP2_00206_00001.dat','SP2_00219_00001.dat',
         'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')

# %%
# for P3 ( 0.7 mg P19015 + 0.37 mg DPPC)
alltemp_s('SP3_00155_00001.dat', 'SP3_00168_00001.dat',
        'SP3_00181_00001.dat','SP3_00194_00001.dat',
        'SP3_00207_00001.dat','SP3_00220_00001.dat',
          'SH2O_00152_00001.dat','SH2O_00165_00001.dat',
         'SH2O_00178_00001.dat','SH2O_00191_00001.dat',
         'SH2O_00204_00001.dat','SH2O_00217_00001.dat')
